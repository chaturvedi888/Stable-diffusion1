# %% [markdown]
# <a href="https://colab.research.google.com/github/chaturvedi888/Basic-Quiz-Game-using-Python/blob/main/Copy_of_upi_frauddetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
credit_card_data = pd.read_csv('/creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 11678  19921  1.208802 -0.401943  0.901086 -0.697416 -1.014073 -0.281932
# 11679  19924 -1.723814  1.389327  1.411353 -0.716019 -1.561864  1.505156
# 11680  19926  1.192037 -0.357840  1.002156 -0.558666 -1.017703 -0.321732
# 11681  19927 -7.773912  4.249596 -5.985636  1.450199 -4.709726 -1.302327
# 11682  19929  1.024814 -1.179948  1.702954 -0.833752 -1.598620  1.270610
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 11678 -0.828187  0.108108  3.018142  ... -0.137886 -0.007707 -0.075264
# 11679 -2.024937 -5.393713  2.156363  ...  5.161661 -1.997550 -0.202928
# 11680 -0.780201  0.062111  3.206257  ... -0.138692  0.082080  0.007441
# 11681 -2.807678  4.890516  0.807323  ...  0.104104 -0.188352 -0.302390
# 11682 -1.786000       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11683 entries, 0 to 11682
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    11683 non-null  int64
#  1   V1      11683 non-null  float64
#  2   V2      11683 non-null  float64
#  3   V3      11683 non-null  float64
#  4   V4      11683 non-null  float64
#  5   V5      11683 non-null  float64
#  6   V6      11683 non-null  float64
#  7   V7      11683 non-null  float64
#  8   V8      11682 non-null  float64
#  9   V9      11682 non-null  float64
#  10  V10     11682 non-null  float64
#  11  V11     11682 non-null  float64
#  12  V12     11682 non-null  float64
#  13  V13     11682 non-null  float64
#  14  V14     11682 non-null  float64
#  15  V15     11682 non-null  float64
#  16  V16     11682 non-null  float64
#  17  V17     11682 non-null  float64
#  18  V18     11682 non-null  float64
#  19  V19     11682 non-null  float64
# ...

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    11633
# 1.0       49
# Name: count, dtype: int64

# %% [markdown]
# Data here his highly inconsistent
#
#
# ---

# %% [markdown]
# 0=normal transaction

# %% [markdown]
# 1=fraud transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    11633.000000
# mean        62.572337
# std        178.797878
# min          0.000000
# 25%          5.180000
# 50%         15.950000
# 75%         50.000000
# max       7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      49.000000
# mean      103.646735
# std       330.135333
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         3.790000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#taking only 492 samples out of 284315 samples of class 1 so that we can train out model accordingly
legit_sample = legit.sample(n=492)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 5966    6627 -2.959331  4.603697 -4.797899  1.652080 -1.114776 -1.498934
# 4852    4355 -0.858498  1.044563  1.668608  1.495705  0.374644  0.178894
# 4752    4196 -2.031015 -0.594523  2.111648  0.778915  2.309889  0.436218
# 1261     973 -0.770968 -0.070879  0.998146 -1.792216  0.040765 -0.850322
# 11071  19122 -3.128666  2.183989 -2.227130  1.279949 -1.684799 -1.019170
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 5966  -1.847467  2.938035  0.516482  ... -0.089444 -0.266905  0.562520
# 4852   0.862716 -0.005410  0.024586  ...  0.149262  0.490847 -0.198098
# 4752  -0.319788  0.538035  0.909764  ...  0.049542  0.181097  0.116846
# 1261   0.489440  0.086829 -1.643236  ...  0.053904 -0.148724  0.204873
# 11071 -0.721197  1.941519  0.629405  ...  0.074377  0.189584 -0.044702
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time         V1        V2         V3         V4         V5        V6  \
# 10690  18088 -12.224021  3.854150 -12.466766   9.648311  -2.726961 -4.445610
# 10801  18399 -14.474437  6.503185 -17.712632  11.270352  -4.150142 -3.372098
# 10891  18675 -12.339603  4.488267 -16.587073  10.107274 -10.420199  0.130670
# 10897  18690 -15.398845  7.472324 -19.026912  11.165526  -6.893856 -2.120937
# 11343  19762 -14.179165  7.421370 -21.405836  11.927512  -7.974281 -2.202710
#
#               V7        V8        V9  ...       V21       V22        V23  \
# 10690 -21.922811  0.320792 -4.433162  ... -1.159830 -1.504119 -19.254328
# 10801 -16.535807 -1.443947 -6.815273  ... -2.475962  0.342391  -3.564508
# 10891 -15.600323 -1.157696 -5.304631  ... -2.089610  1.745315   1.376816
# 10897 -14.913330 -0.721214 -7.175097  ... -2.444884  0.727495  -0.345078
# 11343 -15.471612 -0.356595 -6.380125  ... -2.366836  1.130955   0.991153
#
# ...

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0     7418.957317 -0.238320  0.211713  0.879267  0.188117 -0.073524
# 1.0    11037.265306 -3.064862  4.008973 -7.336847  6.060331 -1.951918
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.109295 -0.103223 -0.005798  0.894623  ...  0.002993 -0.075927
# 1.0   -1.970106 -5.100011  0.977442 -2.509118  ...  0.375559  0.468232
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.130873 -0.026610 -0.002712  0.120212  0.080810 -0.009234 -0.012824
# 1.0   -0.088481 -0.427921 -0.367523 -0.136910  0.285971  0.603784  0.149533
#
#            Amount
# Class
# 0.0     64.548476
# 1.0    103.646735
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time         V1        V2         V3         V4         V5        V6  \
# 5966    6627  -2.959331  4.603697  -4.797899   1.652080  -1.114776 -1.498934
# 4852    4355  -0.858498  1.044563   1.668608   1.495705   0.374644  0.178894
# 4752    4196  -2.031015 -0.594523   2.111648   0.778915   2.309889  0.436218
# 1261     973  -0.770968 -0.070879   0.998146  -1.792216   0.040765 -0.850322
# 11071  19122  -3.128666  2.183989  -2.227130   1.279949  -1.684799 -1.019170
# ...      ...        ...       ...        ...        ...        ...       ...
# 10690  18088 -12.224021  3.854150 -12.466766   9.648311  -2.726961 -4.445610
# 10801  18399 -14.474437  6.503185 -17.712632  11.270352  -4.150142 -3.372098
# 10891  18675 -12.339603  4.488267 -16.587073  10.107274 -10.420199  0.130670
# 10897  18690 -15.398845  7.472324 -19.026912  11.165526  -6.893856 -2.120937
# 11343  19762 -14.179165  7.421370 -21.405836  11.927512  -7.974281 -2.202710
#
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (541, 30) (432, 30) (109, 30)

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
# training the RandomForestClassifier Model with Training Data
clf = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)
clf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=42)

# %%
# training the DecisionTreeClassifier Model with Training Data
c = DecisionTreeClassifier(max_depth=5, random_state=42)
c.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
# accuracy on training data
from sklearn.metrics import accuracy_score

# Train Logistic Regression model
model.fit(X_train, Y_train)

# Predictions and accuracy for Logistic Regression
X_train_prediction_lr = model.predict(X_train)
training_data_accuracy_lr = accuracy_score(X_train_prediction_lr, Y_train)

# Predictions and accuracy for Random Forest
X_train_prediction_rf = clf.predict(X_train)
training_data_accuracy_rf = accuracy_score(X_train_prediction_rf, Y_train)

# Predictions and accuracy for Decision Tree
X_train_prediction_dt = c.predict(X_train)
training_data_accuracy_dt = accuracy_score(X_train_prediction_dt, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print('Accuracy on Training data using logistic regression: ', training_data_accuracy_lr)
print('Accuracy on Training data using random forest classifier: ', training_data_accuracy_rf)
print('Accuracy on Training data using decision tree classifier: ', training_data_accuracy_dt)
# Out:
# Accuracy on Training data using logistic regression:  0.9884259259259259
# Accuracy on Training data using random forest classifier:  0.9953703703703703
# Accuracy on Training data using decision tree classifier:  1.0

# %%
# accuracy on test data
X_test_prediction_lr = model.predict(X_test)
test_data_accuracy_lr = accuracy_score(X_test_prediction_lr, Y_test)

X_test_prediction_rf = clf.predict(X_test)
test_data_accuracy_rf = accuracy_score(X_test_prediction_rf, Y_test)

X_test_prediction_dt = c.predict(X_test)
test_data_accuracy_dt = accuracy_score(X_test_prediction_dt, Y_test)

# %%
print('Accuracy score on Test Data using logistic regression : ', test_data_accuracy_lr)
print('Accuracy score on Test Data random forest classifier : ', test_data_accuracy_rf)
print('Accuracy score on Test Data decision tree classifier: ', test_data_accuracy_dt)
# Out:
# Accuracy score on Test Data using logistic regression :  0.9908256880733946
# Accuracy score on Test Data random forest classifier :  0.9908256880733946
# Accuracy score on Test Data decision tree classifier:  0.9724770642201835
